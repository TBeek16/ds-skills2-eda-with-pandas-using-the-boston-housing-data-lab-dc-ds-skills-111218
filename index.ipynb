# %% [markdown]
# # Project - EDA with Pandas Using the Boston Housing Data

# %% [markdown]
# ## Introduction
#
# In this section you've learned a lot about importing, cleaning up, analysing (using descriptive statistics) and visualizing data. In this more free form project you'll get a chance to practice all of these skills with the Boston Housing data set,  which contains housing values in suburbs of Boston. The Boston Housing Data is commonly used by aspiring data scientists.

# %% [markdown]
# ## Objectives
# You will be able to:
# * Show mastery of the content covered in this section

# %% [markdown]
# # Goals
#
# Use your data munging and visualization skills to conduct an exploratory analysis of the dataset below. At minimum, this should include:
#
# * Loading the data (which is stored in the file train.csv)
# * Use built-in python functions to explore measures of centrality and dispersion for at least 3 variables
# * Create *meaningful* subsets of the data using selection operations using `.loc`, `.iloc` or related operations. Explain why you used the chosen subsets and do this for 3 possible 2-way splits. State how you think the 2 measures of centrality and/or dispersion might be different for each subset of the data. Examples of potential splits:
#     - Create a 2 new dataframes based on your existing data, where one contains all the properties next to the Charles river, and the other one contains properties that aren't.
#     - Create 2 new datagrames based on a certain split for crime rate.
# * Next, use histograms and scatterplots to see whether you observe differences for the subsets of the data. Make sure to use subplots so it is easy to compare the relationships.

# %% [markdown]
# # Variable Descriptions
#
# This data frame contains the following columns:
#
# #### crim
# per capita crime rate by town.
#
# #### zn
# proportion of residential land zoned for lots over 25,000 sq.ft.
#
# #### indus
# proportion of non-retail business acres per town.
#
# #### chas
# Charles River dummy variable (= 1 if tract bounds river; 0 otherwise).
#
# #### nox
# nitrogen oxides concentration (parts per 10 million).
#
# #### rm
# average number of rooms per dwelling.
#
# #### age
# proportion of owner-occupied units built prior to 1940.
#
# #### dis
# weighted mean of distances to five Boston employment centres.
#
# #### rad
# index of accessibility to radial highways.
#
# #### tax
# full-value property-tax rate per $10,000.
#
# #### ptratio
# pupil-teacher ratio by town.
#
# #### black
# 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town.
#
# #### lstat
# lower status of the population (percent).
#
# #### medv
# median value of owner-occupied homes in $10000s.
#
#
#
# Source
# Harrison, D. and Rubinfeld, D.L. (1978) Hedonic prices and the demand for clean air. J. Environ. Economics and Management 5, 81–102.
#
# Belsley D.A., Kuh, E. and Welsch, R.E. (1980) Regression Diagnostics. Identifying Influential Data and Sources of Collinearity. New York: Wiley.

# %% [markdown]
# ## Summary
#
# Congratulations, you've completed your first "freeform" exploratory data analysis of a popular data set!

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("train.csv")
df.head()
# Out:
#    ID     crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0   1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1   2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2   4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 3   5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# 4   7  0.08829  12.5   7.87     0  0.524  6.012  66.6  5.5605    5  311
#
#    ptratio   black  lstat  medv
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     18.7  394.63   2.94  33.4
# 3     18.7  396.90   5.33  36.2
# 4     15.2  395.60  12.43  22.9

# %%
# Use .describe() to return values for dispersion and centrality
df.describe()
# Out:
#                ID        crim          zn       indus        chas         nox  \
# count  333.000000  333.000000  333.000000  333.000000  333.000000  333.000000
# mean   250.951952    3.360341   10.689189   11.293483    0.060060    0.557144
# std    147.859438    7.352272   22.674762    6.998123    0.237956    0.114955
# min      1.000000    0.006320    0.000000    0.740000    0.000000    0.385000
# 25%    123.000000    0.078960    0.000000    5.130000    0.000000    0.453000
# 50%    244.000000    0.261690    0.000000    9.900000    0.000000    0.538000
# 75%    377.000000    3.678220   12.500000   18.100000    0.000000    0.631000
# max    506.000000   73.534100  100.000000   27.740000    1.000000    0.871000
#
#                rm         age         dis         rad         tax     ptratio  \
# count  333.000000  333.000000  333.000000  333.000000  333.000000  333.000000
# mean     6.265619   68.226426    3.709934    9.633634  409.279279   18.448048
# ...

# %%
# Analyzing three variables
df["crim"].mean()
df["age"].quantile(.2)
df["indus"].cumsum()
# Out:
# 0         2.31
# 1         9.38
# 2        11.56
# 3        13.74
# 4        21.61
# 5        29.48
# 6        37.35
# 7        45.22
# 8        53.36
# 9        61.50
# 10       69.64
# 11       77.78
# 12       85.92
# 13       94.06
# 14      102.20
# 15      110.34
# 16      118.48
# 17      126.62
# 18      134.76
# 19      142.90
# 20      151.04
# 21      157.00
# 22      159.95
# 23      162.90
# 24      169.81
# 25      176.72
# 26      183.63
# 27      190.54
# 28      197.45
# 29      204.36
#         ...
# 303    3247.18
# 304    3265.28
# 305    3283.38
# 306    3301.48
# 307    3319.58
# 308    3337.68
# 309    3355.78
# 310    3373.88
# 311    3391.98
# 312    3410.08
# 313    3428.18
# 314    3446.28
# 315    3464.38
# 316    3482.48
# 317    3500.58
# 318    3518.68
# 319    3536.78
# 320    3554.88
# 321    3572.98
# 322    3600.72
# 323    3628.46
# 324    3656.20
# 325    3683.94
# 326    3693.63
# 327    3703.32
# 328    3713.01
# 329    3724.94
# 330    3736.87
# ...

# %%
# Aim for large lots and regular lots
large_lots = df.loc[(df["zn"] > df.zn.quantile(0.75)),:]
reg_lots = df.loc[(df["zn"] <= df.zn.quantile(0.75)),:]
large_lots.describe()
# Out:
#                ID       crim          zn      indus       chas        nox  \
# count   79.000000  79.000000   79.000000  79.000000  79.000000  79.000000
# mean   208.898734   0.132690   44.107595   4.182278   0.050633   0.453418
# std    101.050203   0.187314   26.339459   2.389795   0.220648   0.067420
# min      1.000000   0.006320   17.500000   0.740000   0.000000   0.385000
# 25%     89.000000   0.028870   22.000000   2.805000   0.000000   0.416100
# 50%    249.000000   0.054790   33.000000   3.970000   0.000000   0.433000
# 75%    283.500000   0.144810   67.500000   5.225000   0.000000   0.453000
# max    353.000000   0.825260  100.000000  15.040000   1.000000   0.647000
#
#               rm        age        dis        rad         tax    ptratio  \
# count  79.000000  79.000000  79.000000  79.000000   79.000000  79.000000
# mean    6.741291  41.340506   5.958453   4.531646  291.177215  16.806329
# std     0.595449  22.602402   2.027938   1.946960   57.619610   2.144243
# ...

# %%
reg_lots.describe()
# Out:
#                ID        crim          zn       indus        chas         nox  \
# count  254.000000  254.000000  254.000000  254.000000  254.000000  254.000000
# mean   264.031496    4.364217    0.295276   13.505236    0.062992    0.589406
# std    157.533982    8.164526    1.902104    6.465570    0.243428    0.107401
# min      2.000000    0.024980    0.000000    1.890000    0.000000    0.409000
# 25%    125.500000    0.136008    0.000000    7.870000    0.000000    0.510000
# 50%    234.500000    0.625475    0.000000   18.100000    0.000000    0.580000
# 75%    415.750000    5.645045    0.000000   18.100000    0.000000    0.677000
# max    506.000000   73.534100   12.500000   27.740000    1.000000    0.871000
#
#                rm         age         dis         rad         tax     ptratio  \
# count  254.000000  254.000000  254.000000  254.000000  254.000000  254.000000
# mean     6.117673   76.588583    3.010591   11.220472  446.011811   18.958661
# ...

# %%
# Look at buildings with more than 50% built before 1940
old_bldgs = df.loc[(df["age"] > 50),:]
new_bldgs = df.loc[(df["age"] <= 50),:]

# %%
plt.figure()
plt.boxplot([old_bldgs.nox, new_bldgs.nox])
plt.xticks(ticks = [1,2], labels = ["Old", "New"])
plt.title("NOX in Old and New Buildings, Boston, MA")
plt.show()
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-8-f448c062e705> in <module>()
#       1 plt.figure()
#       2 plt.boxplot([old_bldgs.nox, new_bldgs.nox])
# ----> 3 plt.xticks(ticks = [1,2], labels = ["Old", "New"])
#       4 plt.title("NOX in Old and New Buildings, Boston, MA")
#       5 plt.show()
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/matplotlib/pyplot.py in xticks(*args, **kwargs)
#    1722     if len(kwargs):
#    1723         for l in labels:
# -> 1724             l.update(kwargs)
#    1725
#    1726     return locs, silent_list('Text xticklabel', labels)
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/matplotlib/text.py in update(self, kwargs)
#     183         sentinel = object()  # bbox can be None, so use another sentinel.
#     184         bbox = kwargs.pop("bbox", sentinel)
# --> 185         super(Text, self).update(kwargs)
#     186         if bbox is not sentinel:
#     187             self.set_bbox(bbox)
#
# ...

# %%
plt.figure()
plt.boxplot([old_bldgs["nox"], new_bldgs["nox"]])
plt.xticks(ticks = [1,2], labels = ["Old", "New"])
plt.title("NOX in Old and New Buildings, Boston, MA")
plt.show()
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-9-bd5fc03f461e> in <module>()
#       1 plt.figure()
#       2 plt.boxplot([old_bldgs["nox"], new_bldgs["nox"]])
# ----> 3 plt.xticks(ticks = [1,2], labels = ["Old", "New"])
#       4 plt.title("NOX in Old and New Buildings, Boston, MA")
#       5 plt.show()
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/matplotlib/pyplot.py in xticks(*args, **kwargs)
#    1722     if len(kwargs):
#    1723         for l in labels:
# -> 1724             l.update(kwargs)
#    1725
#    1726     return locs, silent_list('Text xticklabel', labels)
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/matplotlib/text.py in update(self, kwargs)
#     183         sentinel = object()  # bbox can be None, so use another sentinel.
#     184         bbox = kwargs.pop("bbox", sentinel)
# --> 185         super(Text, self).update(kwargs)
#     186         if bbox is not sentinel:
#     187             self.set_bbox(bbox)
#
# ...

# %%
# Define a new figure with matplotlib's .plot() function. 
fig = plt.figure()

# Add new axes to the figure with absolute positions
ax1 = fig.add_axes([0, 0, 1, 1]) # main axes
ax2 = fig.add_axes([0.7, 0.6, 0.3, 0.3])

ax1.hist(old_bldgs.nox)
ax1.set_title("Old Buildings")
ax1.set_xlabel("NOx")

ax2.hist(new_bldgs.nox)
ax2.set_title("New Buildings")
ax2.set_xlabel("NOx")

plt.show()

# %%
# Define a new figure with matplotlib's .plot() function. 
fig = plt.figure()

# Add new axes to the figure with absolute positions
ax1 = fig.add_axes([0, 0, .4, .4]) # main axes
ax2 = fig.add_axes([0, 0.6, .4, .4])

ax1.hist(old_bldgs.nox)
ax1.set_title("Old Buildings")
ax1.set_xlabel("NOx")
# Set the limits of x and y for 1st plot 
ax1.set_xlim(0.3, 0.9), ax1.set_ylim(0, 50)

ax2.hist(new_bldgs.nox)
ax2.set_title("New Buildings")
ax2.set_xlabel("NOx")
# Set the limits of x and y for 2nd plot
ax2.set_xlim(0.3, 0.9), ax2.set_ylim(0, 50)

plt.show()

# %%
df.plot.scatter(x = "age", y = "nox")

# %%
df.plot.scatter(x = "crim", y = "medv")

# %%
df.plot.scatter(x = "age", y = "medv")

# %%
df.plot.scatter(x = "nox", y = "medv")
df.plot.scatter
# Out:
# <bound method FramePlotMethods.scatter of <pandas.plotting._core.FramePlotMethods object at 0x7f2c046fbc50>>

# %%
df.dis.describe()
# Out:
# count    333.000000
# mean       3.709934
# std        1.981123
# min        1.129600
# 25%        2.122400
# 50%        3.092300
# 75%        5.116700
# max       10.710300
# Name: dis, dtype: float64

# %%
df.dis.hist()

# %%
# Let's see where distance value is first less than median, and then if it is greater than the median
near = df.loc[(df.dis <= df.dis.quantile(0.5)),]
far = df.loc[(df.dis > df.dis.quantile(0.5)),]

# Define a new figure with matplotlib's .plot() function. 
fig = plt.figure()

# Add new axes to the figure with absolute positions
ax1 = fig.add_axes([0, 0, .4, .4]) # main axes
ax2 = fig.add_axes([0, 0.6, .4, .4])

ax1.hist(near.nox)
ax1.set_title("Near Buildings")
ax1.set_xlabel("NOx")
# Set the limits of x and y for 1st plot 
ax1.set_xlim(0.3, 0.9), ax1.set_ylim(0, 50)

ax2.hist(far.nox)
ax2.set_title("Far Buildings")
ax2.set_xlabel("NOx")
# Set the limits of x and y for 2nd plot
ax2.set_xlim(0.3, 0.9), ax2.set_ylim(0, 50)

plt.show()

# %%
# Define a new figure with matplotlib's .plot() function. 
figure = plt.figure(figsize = (10,6))

# Add new axes to the figure with absolute positions
ax1 = figure.add_subplot(121)
ax2 = figure.add_subplot(122)

ax1.scatter(x = near.nox, y = near.medv)
ax1.set_xlabel("Near")
ax2.scatter(x = far.nox, y = far.medv, color = 'orange')
ax2.set_xlabel("Far")

plt.show()

# %%
# create a new column called Close
df.loc[df.dis > df.dis.quantile(0.75), 'close'] = 0
df.loc[df.dis <= df.dis.quantile(0.75), 'close'] = 1
df.head()

# Define a new figure with matplotlib's .plot() function. 
figure = plt.figure(figsize = (10,6))

# Add new axes to the figure with absolute positions
ax1 = figure.add_subplot(121)
ax2 = figure.add_subplot(122)

ax1.scatter(x = df.loc[df.close == 1, 'nox'], y = close.medv)
ax1.set_xlabel("Near")
ax2.scatter(x = far.nox, y = far.medv, color = 'orange')
ax2.set_xlabel("Far")

plt.show()
# Out:
#    ID     crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0   1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1   2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2   4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 3   5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# 4   7  0.08829  12.5   7.87     0  0.524  6.012  66.6  5.5605    5  311
#
#    ptratio   black  lstat  medv  near
# 0     15.3  396.90   4.98  24.0   1.0
# 1     17.8  396.90   9.14  21.6   1.0
# 2     18.7  394.63   2.94  33.4   0.0
# 3     18.7  396.90   5.33  36.2   0.0
# 4     15.2  395.60  12.43  22.9   0.0
